# %% [markdown]
# <a href="https://colab.research.google.com/github/Vasavipilli/FMML_ASSIGNMENTS_AND_LABS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 13:56:12--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  61.5MB/s    in 1.1s
#
# 2024-03-26 13:56:16 (61.5 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 13084  1507.06970v2  We introduce and analyze stochastic optimizati...  stat
# 11255  1506.05173v2  We introduce single-set spectral sparsificatio...  stat
# 40987   1404.0453v1  This paper aims at providing a survey on the p...    cs
# 5627   1505.02434v1  The Gaussian process latent variable model (GP...  stat
# 5593    1309.5643v3  Multiple instance learning (MIL) is concerned ...  stat
# ...             ...                                                ...   ...
# 22345  1602.08418v1  In this paper, we present a framework for fitt...  stat
# 21697   0906.4391v1  Selecting important features in non-linear or ...  stat
# 27524  1703.09507v3  In recent years, the performance of face verif...    cs
# 21796  1604.01075v1  Many retailers today employ inventory manageme...  stat
# 31611  1803.07544v1  Increasing malicious users have sought practic...    cs
#
#                                                    title  year  \
# 13084  Perturbed Iterate Analysis for Asynchronous St...  2015
# 11255  Feature Selection for Ridge Regression with Pr...  2015
# 40987  Cellular Automata and Its Applications in Bioi...  2014
# 5627   Spike and Slab Gaussian Process Latent Variabl...  2015
# 5593   Multiple Instance Learning with Bag Dissimilar...  2013
# ...                                                  ...   ...
# 22345  Multivariate Hawkes Processes for Large-scale ...  2016
# 21697         KNIFE: Kernel Iterative Feature Extraction  2009
# 27524  L2-constrained Softmax Loss for Discriminative...  2017
# 21796  A Dynamic Bayesian Network Model for Inventory...  2016
# 31611  C3PO: Database and Benchmark for Early-stage M...  2018
#
#                                                 keywords
# 13084  [introduce, stochastic, optimization, perturbe...
# 11255  [introduce, sparsification, deterministic, sel...
# 40987  [providing, addressed, bioinformatics, algorit...
# 5627   [probabilistic, dimensionality, reduction, var...
# 5593   [concerned, individual, ambiguous, supervised,...
# ...                                                  ...
# 22345  [framework, multivariate, processes, framework...
# 21697  [selecting, important, difficult, challenge, c...
# 27524  [performance, verification, significantly, con...
# 21796  [retailers, inventory, management, assumption,...
# 31611  [increasing, malicious, practices, technology,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 13084    [introduce, stochastic, optimization, perturbe...
# 11255    [introduce, sparsification, deterministic, sel...
# 40987    [providing, addressed, bioinformatics, algorit...
# 5627     [probabilistic, dimensionality, reduction, var...
# 5593     [concerned, individual, ambiguous, supervised,...
#                                ...
# 731      [challenges, artificial, intelligence, effecti...
# 26339    [estimating, convolutional, components, optimi...
# 5668     [parametric, approaches, regression, propertie...
# 32446    [supervised, exponential, characterization, ge...
# 30960    [recognition, sequences, robustness, convoluti...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8733 words.
# Out of those 4565 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ca7ffb76-3016-4b18-a92b-cefc256392a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca7ffb76-3016-4b18-a92b-cefc256392a4")) {                    Plotly.newPlot(                        "ca7ffb76-3016-4b18-a92b-cefc256392a4",                        [{"x":["algorithms","assumptions","demonstrate","implementations","algorithm","framework","coordinate","experimentally","perturbed","asynchronous","operating","magnitude","optimization","convergence","stochastic","introduce","synthetic","unsupervised","technique","sparsification","guarantees","experimental","randomized","comparable","generalization","regularized","classification","regression","selection","deterministic","experiments","addressed","extensive","applications","bioinformatics","researchers","logically","addressing","conferences","providing","application","literature","intuition","conducted","considered","procedure","effectiveness","selecting","thresholding","dimensions","simulated","retrieval","efficient","inference","parameters","likelihood","variational","relevance","probabilistic","processes","multimedia","principled","dimensionality","demonstrated","reduction","variables","outperforms","particular","ambiguous","represent","computationally","generalize","dissimilarities","inexpensive","individual","alternatives","supervised","relationship","therefore","representation","dissimilarity","definitions","concerned","additional","specialized","competitive","instances","facilitate","outperforming","correlations","integrated","interesting","automatic","structured","recognition","benchmark","convolutional","effective","available","including","descriptions","practical","flexibility","information","privileged","compatible","diffusion","guaranteeing","alternative","locations","interpolation","gaussians","potential","undersampling","transform","estimating","reconstructing","undersampled","arbitrary","reconstruction","validated","nonnegative","accurately","uniformly","propagator","integrates","replacement","robustness","optimized","correction","multiplication","techniques","resulting","probability","polynomial","traditional","classifier","distortion","complexity","specifically","minimizing","strategies","correcting","quantization","redundancy","corrupted","classifiers","replication","constrained","approximation","approaches","constraints","centralized","empirically","performance","theoretical","distributed","horizontally","submodular","provision","maximization","corresponding","eigenvalue","regarding","uncorrelated","different","consequences","rademacher","projective","connection","existence","fundamental","satisfying","environment","properties","annotated","verification","improvement","predicting","collected","occurrences","occurrence","determine","relational","attribute","statistics","hierarchical","nonlinearities","knowledge","performances","solutions","agricultural","multimodal","hyperspectral","multiclass","resolutions","discovering","experience","minimized","requirements"],"y":[583,69,581,38,824,563,26,40,6,15,27,63,325,107,116,338,147,157,265,2,56,404,25,94,127,44,510,117,154,52,621,42,184,447,10,59,3,33,2,98,259,145,17,87,135,112,229,43,13,42,48,102,412,214,215,61,57,32,165,118,9,21,55,100,97,125,288,259,18,121,84,41,2,10,130,29,189,69,152,389,12,24,19,119,28,116,103,35,39,26,59,82,192,118,388,196,388,265,269,263,32,148,38,705,5,15,22,3,116,41,20,9,145,1,80,67,15,2,81,114,34,10,59,14,1,19,10,100,48,24,9,410,170,143,53,188,141,25,230,180,60,98,8,26,20,21,106,0,61,113,414,159,5,92,893,138,89,0,8,3,27,128,4,37,2,754,8,6,4,45,41,85,19,125,197,82,49,152,74,75,14,30,54,32,52,48,110,6,375,39,184,4,43,14,7,8,36,38,8,59],"type":"bar"},{"x":["algorithms","assumptions","demonst ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4565,), (4565, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8041666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>One</span> <span style=''>shot</span> <span style=''>Face</span> <span style='background-color:rgba(0, 255, 0, 0.6510638297872341);'>Recognition</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Promoting</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Underrepresented</span> <span style=''>Classes</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>training</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>face</span> <span style='background-color:rgba(0, 255, 0, 0.3017751479289941);'>identification</span> <span style=''>model</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>imbalanced</span> <span style=''>training</span> <span style=''>data</span> <span style=''>This</span> <span style=''>problem</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>naturally</span> <span style=''>exists</span> <span style=''>in</span> <span style=''>many</span> <span style=''>real</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scenarios</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>large</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>celebrity</span> <span style='background-color:rgba(0, 255, 0, 0.6510638297872341);'>recognition</span> <span style=''>movie</span> <span style=''>actor</span> <span style='background-color:rgba(0, 255, 0, 0.823529411764706);'>annotation</span> <span style=''>etc</span> <span style=''>Our</span> <span style=''>solution</span> <span style=''>contains</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>First</span> <span style=''>we</span> <span style=''>build</span> <span style=''>a</span> <span style=''>face</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.673469387755102);'>extraction</span> <span style=''>model</span> <span style=''>and</span> <span style=''>improve</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>especially</span> <span style=''>for</span> <span style=''>the</span> <span style=''>persons</span> <span style=''>with</span> <span style=''>very</span> <span style=''>limited</span> <span style=''>training</span> <span style=''>samples</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introducing</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularizer</span> <span style=''>to</span> <span style=''>the</span> <span style=''>cross</span> <span style=''>entropy</span> <span style=''>loss</span> <span style=''>for</span> <span style=''>the</span> <span style=''>multi</span> <span style=''>nomial</span> <span style=''>logistic</span> <span style='background-color:rgba(255, 0, 0, 0.5185185185185186);'>regression</span> <span style=''>(MLR)</span> <span style=''>learning</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularizer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>encourages</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>directions</span> <span style=''>of</span> <span style=''>the</span> <span style=''>face</span> <span style=''>features</span> <span style=''>from</span> <span style=''>the</span> <span style=''>same</span> <span style=''>class</span> <span style=''>to</span> <span style=''>be</span> <span style=''>close</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>direction</span> <span style=''>of</span> <span style=''>their</span> <s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Structured</span> <span style=''>Sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Component</span> <span style=''>Analysis</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>sparse</span> <span style=''>PCA</span> <span style=''>or</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>learning</span> <span style=''>where</span> <span style=''>the</span> <span style=''>sparsity</span> <span style=''>patterns</span> <span style=''>of</span> <span style=''>all</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>elements</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style=''>to</span> <span style=''>belong</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prespecified</span> <span style=''>set</span> <span style=''>of</span> <span style=''>shapes</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>emphstructured</span> <span style=''>sparse</span> <span style=''>PCA</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>recently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>by</span> <span style=''>1</span> <span style=''>While</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classical</span> <span style=''>sparse</span> <span style=''>priors</span> <span style=''>only</span> <span style=''>deal</span> <span style=''>with</span> <span style=''>textitcardinality</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>we</span> <span style=''>use</span> <span style=''>encodes</span> <span style=''>higher</span> <span style=''>order</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>about</span> <span style=''>the</span> <span style=''>data</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>and</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>this</span> <span style=''>problem</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Experiments</span> <span style=''>with</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style=''>tasks</span> <span style=''>face</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>and</span> <span style=''>the</span> <span style=''>study</span> <span style=''>of</span> <span style=''>the</span> <span style=''>dynamics</span> <span style=''>of</span> <span style=''>a</span> <span style=''>protein</span> <span style=''>complex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style=''>benefits</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style=''>approach</span> <span style=''>over</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Large</span> <span style=''>Sample</span> <span style=''>Learning</span> <span style=''>of</span> <span style=''>Bayesian</span> <span style=''>Networks</span> <span style=''>is</span> <span style=''>NP</span> <span style=''>Hard</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>results</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style=''>learn</span> <span style=''>discrete</span> <span style=''>variable</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>from</span> <span style=''>data</span> <span style=''>Our</span> <span style=''>results</span> <span style=''>apply</span> <span style=''>whenever</span> <span style=''>the</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>uses</span> <span style=''>a</span> <span style=''>scoring</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <span style=''>that</span> <span style=''>favors</span> <span style=''>the</span> <span style=''>simplest</span> <span style=''>model</span> <span style=''>able</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3908045977011494);'>represent</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>exactly</span> <span style=''>Our</span> <span style=''>results</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>therefore</span> <span style=''>hold</span> <span style=''>whenever</span> <span style=''>the</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>uses</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style=''>scoring</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <span style=''>and</span> <span style=''>is</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>sufficiently</span> <span style=''>large</span> <span style=''>dataset</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifying</span> <span style=''>high</span> <span style=''>scoring</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>is</span> <span style=''>hard</span> <span style=''>even</span> <span style=''>when</span> <span style=''>we</span> <span style=''>are</span> <span style=''>given</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3409090909090909);'>independence</span> <span style=''>oracle</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.32063492063492055);'>inference</span> <span style=''>oracle</span> <span style=''>andor</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>oracle</span> <span style=''>Our</span> <span style=''>negative</span> <span style=''>results</span> <span style=''>also</span> <span style=''>apply</span> <span style=''>to</span> <span style=''>the</span> <span style=''>learning</span> <span style=''>of</span> <span style=''>discrete</span> <span style=''>variable</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>in</span> <span style=''>which</span> <span style=''>each</span> <span style=''>node</span> <span style=''>has</span> <span style=''>at</span> <span style=''>most</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Towards</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Conceptual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Compression</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>simple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recurrent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>auto</span> <span style=''>encoder</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>improves</span> <span style=''>image</span> <span style=''>modeling</span> <span style=''>The</span> <span style=''>system</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represents</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>in</span> <span style=''>latent</span> <span style=''>variable</span> <span style=''>models</span> <span style=''>for</span> <span style=''>both</span> <span style=''>the</span> <span style=''>ImageNet</span> <span style=''>and</span> <span style=''>Omniglot</span> <span style=''>datasets</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>it</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>naturally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>separates</span> <span style=''>global</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conceptual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>from</span> <span style=''>lower</span> <span style=''>level</span> <span style=''>details</span> <span style=''>thus</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>addressing</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fundamentally</span> <span style=''>desired</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Furthermore</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>possibility</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restricting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>ourselves</span> <span style=''>to</span> <span style=''>storing</span> <span style=''>only</span> <span style=''>global</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>about</span> <span style=''>an</span> <span style=''>image</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>achieve</span> <span style=''>high</span> <span style=''>quality</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conceptual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compression</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	segmentation (0.06382215847974185)
# 	architecture (0.08963786303334528)
# 	knowledge (0.13445679455001794)
# 	representation (0.13947651487988527)
# 	information (0.2527787737540337)
# 	experimental (0.14485478666188598)
# 	detection (0.12871997131588384)
# 	different (0.27034779490856936)
# 	convolutional (0.13911796342775187)
# 	recognition (0.13911796342775187)
#
# Some Statistics words are:
# 	variables (0.1352560914967678)
# 	estimation (0.16260566882148186)
# 	stochastic (0.13475882645450024)
# 	algorithm (0.3893585280954749)
# 	statistical (0.15564395822973645)
# 	theoretical (0.14818498259572352)
# 	distribution (0.18349080059671805)
# 	dimensional (0.18547986076578815)
# 	inference (0.20686225758329188)
# 	regression (0.18349080059671805)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="25c11c41-5b40-4a43-9c50-4c17f1c2d5cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25c11c41-5b40-4a43-9c50-4c17f1c2d5cf")) {                    Plotly.newPlot(                        "25c11c41-5b40-4a43-9c50-4c17f1c2d5cf",                        [{"x":["algorithms","assumptions","demonstrate","implementations","algorithm","framework","coordinate","experimentally","perturbed","asynchronous","operating","magnitude","optimization","convergence","stochastic","introduce","synthetic","unsupervised","technique","sparsification","guarantees","experimental","randomized","comparable","generalization","regularized","classification","regression","selection","deterministic","experiments","addressed","extensive","applications","bioinformatics","researchers","logically","addressing","conferences","providing","application","literature","intuition","conducted","considered","procedure","effectiveness","selecting","thresholding","dimensions","simulated","retrieval","efficient","inference","parameters","likelihood","variational","relevance","probabilistic","processes","multimedia","principled","dimensionality","demonstrated","reduction","variables","outperforms","particular","ambiguous","represent","computationally","generalize","dissimilarities","inexpensive","individual","alternatives","supervised","relationship","therefore","representation","dissimilarity","definitions","concerned","additional","specialized","competitive","instances","facilitate","outperforming","correlations","integrated","interesting","automatic","structured","recognition","benchmark","convolutional","effective","available","including","descriptions","practical","flexibility","information","privileged","compatible","diffusion","guaranteeing","alternative","locations","interpolation","gaussians","potential","undersampling","transform","estimating","reconstructing","undersampled","arbitrary","reconstruction","validated","nonnegative","accurately","uniformly","propagator","integrates","replacement","robustness","optimized","correction","multiplication","techniques","resulting","probability","polynomial","traditional","classifier","distortion","complexity","specifically","minimizing","strategies","correcting","quantization","redundancy","corrupted","classifiers","replication","constrained","approximation","approaches","constraints","centralized","empirically","performance","theoretical","distributed","horizontally","submodular","provision","maximization","corresponding","eigenvalue","regarding","uncorrelated","different","consequences","rademacher","projective","connection","existence","fundamental","satisfying","environment","properties","annotated","verification","improvement","predicting","collected","occurrences","occurrence","determine","relational","attribute","statistics","hierarchical","nonlinearities","knowledge","performances","solutions","agricultural","multimodal","hyperspectral","multiclass","resolutions","discovering","experience","minimized","requirements","predictions","denoising","minimization","substantially","sophisticated","improving","prediction","discriminatively","collection","functions","expressive","simplistic","propagating","candidate","configurations","transformation","fundamentally","naturally","similarities","illumination","challenging","differing","distributions","overlapping","configuration","variations","appearance","characteristic","descriptors","cumulative","identification","difficulties","embedding","estimation","normalization","employing","inversion","architectures","diversity","recurrent","procedures","curvature","dependent","linearity","architecture","proposals","probabilities","theoretically","incidentally","necessity","resources ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	replication
# 	horizontally
# 	subroutines
# 	segmental
# 	solvation
# 	requisite
# 	chemception
# 	lengthscales
# 	sequentialized
# 	itinerary
# 	optionally
# 	lightspeed
# 	hamiltonians
# 	integrator
# 	compresses
# 	prospective
# 	comorbidity
# 	hemoglobin
# 	seasonality
# 	proteomics
# Some words which never appear in Statistics papers:
# 	logically
# 	conferences
# 	surrounded
# 	neighbours
# 	attenuation
# 	smartphone
# 	navigation
# 	regresses
# 	velocities
# 	repetitive
# 	committed
# 	grounding
# 	wheelchair
# 	surroundings
# 	constitutive
# 	apparently
# 	cooperate
# 	attentive
# 	magnification
# 	configurable

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.081189339084887e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7666666666666667
